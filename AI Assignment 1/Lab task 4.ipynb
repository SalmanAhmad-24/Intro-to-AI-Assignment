# %%
dd = {'s':[('a',3),('b',2),('c',4)],
    'a':[('d',1)],
    'b':[('e',8),('f',7),('d',1)],
    'c':[('e',1),('j',3)],
    'd':[('f',1),('h',1)],
    'e':[('g',1)],
    'f':[('g',5)],
    'h':[('g',1),('f',3)],
    'j':[('e',2)],
    'g':[]}
dd.get('s')
# Out:
# [('a', 3), ('b', 2), ('c', 4)]

# %%
def my(x):
    return x[1]
my(('a',3))
# Out:
# 3

# %%
def build_dcit(lis):
    di  = {}

    for i in lis:
        name = i[0]
        cost = i[1]
        di[name] = cost
        print(di)
    return di
lis=[('a',3),('b',2),('c',4)]
build_dcit(lis)
# Out:
# {'a': 3}
# {'a': 3, 'b': 2}
# {'a': 3, 'b': 2, 'c': 4}
# {'a': 3, 'b': 2, 'c': 4}

# %%
def UCS_new(d,goal):
    
    q = []
    q.append(('s',0))
    explored = []
    
    while len(q)>0:

        print('Queue :  ',q)
        node = q.pop(0)   
        
        if node[0] not in explored:
            explored.append(node[0])
        
        if node[0] == goal:
            return explored 
        
        child = dd.get(node[0])
              
        for i in child:
            
            cost =  i[1] + node[1]
            name = i[0]
            new = (name,cost)

            if new[0] not in explored and new[0] not in build_dcit(q):
                
                q.append(new) 

            elif new[0] in build_dcit(q):

                old_data = build_dcit(q)
                old_cost = old_data[new[0]]
                old_name = new[0]
                old = (old_name,old_cost)

                if new[1] < old[1]:

                    inde = q.index(old)
                    q[inde] = new
                else:
                    pass

        
        q = sorted(q,key= my)
        print(50*'*')
        
    
UCS_new(dd,'g')
# Out:
# Queue :   [('s', 0)]
# i ('a', 3)
# ('a', 3)
# i ('b', 2)
# ('b', 2)
# {'a': 3}
# i ('c', 4)
# ('c', 4)
# {'a': 3}
# {'a': 3, 'b': 2}
# **************************************************
# Queue :   [('b', 2), ('a', 3), ('c', 4)]
# i ('e', 8)
# ('e', 10)
# {'a': 3}
# {'a': 3, 'c': 4}
# i ('f', 7)
# ('f', 9)
# {'a': 3}
# {'a': 3, 'c': 4}
# {'a': 3, 'c': 4, 'e': 10}
# i ('d', 1)
# ('d', 3)
# {'a': 3}
# {'a': 3, 'c': 4}
# {'a': 3, 'c': 4, 'e': 10}
# {'a': 3, 'c': 4, 'e': 10, 'f': 9}
# **************************************************
# Queue :   [('a', 3), ('d', 3), ('c', 4), ('f', 9), ('e', 10)]
# i ('d', 1)
# ('d', 4)
# {'d': 3}
# {'d': 3, 'c': 4}
# {'d': 3, 'c': 4, 'f': 9}
# {'d': 3, 'c': 4, 'f': 9, 'e': 10}
# {'d': 3}
# {'d': 3, 'c': 4}
# {'d': 3, 'c': 4, 'f': 9}
# {'d': 3, 'c': 4, 'f': 9, 'e': 10}
# {'d': 3}
# {'d': 3, 'c': 4}
# {'d': 3, 'c': 4, 'f': 9}
# {'d': 3, 'c': 4, 'f': 9, 'e': 10}
# **************************************************
# Queue :   [('d', 3), ('c', 4), ('f', 9), ('e', 10)]
# i ('f', 1)
# ('f', 4)
# {'c': 4}
# {'c': 4, 'f': 9}
# {'c': 4, 'f': 9, 'e': 10}
# {'c': 4}
# {'c': 4, 'f': 9}
# {'c': 4, 'f': 9, 'e': 10}
# {'c': 4}
# {'c': 4, 'f': 9}
# {'c': 4, 'f': 9, 'e': 10}
# i ('h', 1)
# ('h', 4)
# {'c': 4}
# {'c': 4, 'f': 4}
# {'c': 4, 'f': 4, 'e': 10}
# **************************************************
# Queue :   [('c', 4), ('f', 4), ('h', 4), ('e', 10)]
# i ('e', 1)
# ('e', 5)
# {'f': 4}
# {'f': 4, 'h': 4}
# {'f': 4, 'h': 4, 'e': 10}
# {'f': 4}
# {'f': 4, 'h': 4}
# {'f': 4, 'h': 4, 'e': 10}
# {'f': 4}
# {'f': 4, 'h': 4}
# {'f': 4, 'h': 4, 'e': 10}
# i ('j', 3)
# ('j', 7)
# {'f': 4}
# {'f': 4, 'h': 4}
# {'f': 4, 'h': 4, 'e': 5}
# **************************************************
# Queue :   [('f', 4), ('h', 4), ('e', 5), ('j', 7)]
# i ('g', 5)
# ('g', 9)
# {'h': 4}
# {'h': 4, 'e': 5}
# {'h': 4, 'e': 5, 'j': 7}
# **************************************************
# Queue :   [('h', 4), ('e', 5), ('j', 7), ('g', 9)]
# i ('g', 1)
# ('g', 5)
# {'e': 5}
# {'e': 5, 'j': 7}
# {'e': 5, 'j': 7, 'g': 9}
# {'e': 5}
# {'e': 5, 'j': 7}
# {'e': 5, 'j': 7, 'g': 9}
# {'e': 5}
# {'e': 5, 'j': 7}
# {'e': 5, 'j': 7, 'g': 9}
# i ('f', 3)
# ('f', 7)
# {'e': 5}
# {'e': 5, 'j': 7}
# {'e': 5, 'j': 7, 'g': 5}
# **************************************************
# Queue :   [('e', 5), ('g', 5), ('j', 7)]
# i ('g', 1)
# ('g', 6)
# {'g': 5}
# {'g': 5, 'j': 7}
# {'g': 5}
# {'g': 5, 'j': 7}
# {'g': 5}
# {'g': 5, 'j': 7}
# **************************************************
# Queue :   [('g', 5), ('j', 7)]
# ['s', 'b', 'a', 'd', 'c', 'f', 'h', 'e', 'g']

# %%
graph = {
         'Arad': [('Sibiu', 140), ('Timisoara', 118), ('Zerind', 75)],
         'Sibiu': [('Arad', 140), ('Oradea', 151), ('Fagaras', 99), ('Rimnicu', 80)],
         'Timisoara': [('Arad', 118), ('Lugoj', 111)],
         'Zerind': [('Arad', 75), ('Oradea', 71)],
         'Oradea': [('Zerind', 71), ('Sibiu', 151)],
         'Fagaras': [('Sibiu', 99), ('Bucharest', 211)],
         'Rimnicu': [('Sibiu', 80), ('Craivo', 146), ('Pitesti', 97)],
         'Lugoj': [('Timisoara', 111), ('Mehadia', 70)],
         'Bucharest': [('Giurgiu', 90), ('Urziceni', 85), ('Pitesti', 101), ('Fagaras', 211)],
         'Craivo': [('Dobreta', 120), ('Pitesti', 138), ('Rimnicu', 146)],
         'Pitesti': [('Rimnicu', 97), ('Craivo', 138), ('Bucharest', 101)],
         'Mehadia': [('Dobreta', 75), ('Lugoj', 70)],
         'Giurgiu': [('Bucharest', 90)],
         'Urziceni': [('Bucharest', 85), ('Hirsova', 98), ('Vaslui', 142)],
         'Dobreta': [('Mehadia', 75), ('Craivo', 120)],
         'Hirsova' : [('Eforie', 86), ('Urziceni', 98)],
         'Vaslui' : [('Urziceni', 142), ('Lasi', 92)],
         'Eforie' : [('Hirsova', 86)],
         'Lasi': [('Neamt', 87), ('Vaslui', 92)],
         'Neamt': [('Lasi', 87)],
}

# %%
def UCS_new(d,goal):
    
    q = []
    q.append(('Arad',0))
    explored = []
    
    while len(q)>0:

        print('Queue :  ',q)
        node = q.pop(0)   
        
        if node[0] not in explored:
            explored.append(node[0])
        
        if node[0] == goal:
            return explored 
        
        child = d.get(node[0])
              
        for i in child:

            cost =  i[1] + node[1]
            name = i[0]
            new = (name,cost)

            if new[0] not in explored and new[0] not in build_dcit(q):
                
                q.append(new) 

            elif new[0] in build_dcit(q):

                old_data = build_dcit(q)
                old_cost = old_data[new[0]]
                old_name = new[0]
                old = (old_name,old_cost)
                print("old", old)
                print("new", new)
                if new[1] < old[1]:
                    print("hlll")
                    inde = q.index(old)
                    q[inde] = new
                else:
                    pass

        
        q = sorted(q,key= my)
        print(50*'*')
        
    

UCS_new(graph,'Bucharest')
# Out:
# Queue :   [('Arad', 0)]
# {'Sibiu': 140}
# {'Sibiu': 140}
# {'Sibiu': 140, 'Timisoara': 118}
# **************************************************
# Queue :   [('Zerind', 75), ('Timisoara', 118), ('Sibiu', 140)]
# {'Timisoara': 118}
# {'Timisoara': 118, 'Sibiu': 140}
# {'Timisoara': 118}
# {'Timisoara': 118, 'Sibiu': 140}
# **************************************************
# Queue :   [('Timisoara', 118), ('Sibiu', 140), ('Oradea', 146)]
# {'Sibiu': 140}
# {'Sibiu': 140, 'Oradea': 146}
# {'Sibiu': 140}
# {'Sibiu': 140, 'Oradea': 146}
# **************************************************
# Queue :   [('Sibiu', 140), ('Oradea', 146), ('Lugoj', 229)]
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# old ('Oradea', 146)
# new ('Oradea', 291)
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146, 'Lugoj': 229, 'Fagaras': 239}
# **************************************************
# Queue :   [('Oradea', 146), ('Rimnicu', 220), ('Lugoj', 229), ('Fagaras', 239)]
# {'Rimnicu': 220}
# {'Rimnicu': 220, 'Lugoj': 229}
# {'Rimnicu': 220, 'Lugoj': 229, 'Fagaras': 239}
# {'Rimnicu': 220}
# {'Rimnicu': 220, 'Lugoj': 229}
# {'Rimnicu': 220, 'Lugoj': 229, 'Fagaras': 239}
# **************************************************
# Queue :   [('Rimnicu', 220), ('Lugoj', 229), ('Fagaras', 239)]
# {'Lugoj': 229}
# {'Lugoj': 229, 'Fagaras': 239}
# {'Lugoj': 229}
# {'Lugoj': 229, 'Fagaras': 239}
# {'Lugoj': 229}
# {'Lugoj': 229, 'Fagaras': 239}
# {'Lugoj': 229, 'Fagaras': 239, 'Craivo': 366}
# **************************************************
# Queue :   [('Lugoj', 229), ('Fagaras', 239), ('Pitesti', 317), ('Craivo', 366)]
# {'Fagaras': 239}
# {'Fagaras': 239, 'Pitesti': 317}
# {'Fagaras': 239, 'Pitesti': 317, 'Craivo': 366}
# {'Fagaras': 239}
# {'Fagaras': 239, 'Pitesti': 317}
# {'Fagaras': 239, 'Pitesti': 317, 'Craivo': 366}
# **************************************************
# Queue :   [('Fagaras', 239), ('Mehadia', 299), ('Pitesti', 317), ('Craivo', 366)]
# {'Mehadia': 299}
# {'Mehadia': 299, 'Pitesti': 317}
# {'Mehadia': 299, 'Pitesti': 317, 'Craivo': 366}
# {'Mehadia': 299}
# {'Mehadia': 299, 'Pitesti': 317}
# {'Mehadia': 299, 'Pitesti': 317, 'Craivo': 366}
# **************************************************
# Queue :   [('Mehadia', 299), ('Pitesti', 317), ('Craivo', 366), ('Bucharest', 450)]
# {'Pitesti': 317}
# {'Pitesti': 317, 'Craivo': 366}
# {'Pitesti': 317, 'Craivo': 366, 'Bucharest': 450}
# {'Pitesti': 317}
# {'Pitesti': 317, 'Craivo': 366}
# {'Pitesti': 317, 'Craivo': 366, 'Bucharest': 450}
# {'Pitesti': 317, 'Craivo': 366, 'Bucharest': 450, 'Dobreta': 374}
# **************************************************
# Queue :   [('Pitesti', 317), ('Craivo', 366), ('Dobreta', 374), ('Bucharest', 450)]
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# old ('Craivo', 366)
# new ('Craivo', 455)
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# old ('Bucharest', 450)
# new ('Bucharest', 418)
# hlll
# **************************************************
# Queue :   [('Craivo', 366), ('Dobreta', 374), ('Bucharest', 418)]
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# old ('Dobreta', 374)
# new ('Dobreta', 486)
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# **************************************************
# Queue :   [('Dobreta', 374), ('Bucharest', 418)]
# {'Bucharest': 418}
# {'Bucharest': 418}
# **************************************************
# Queue :   [('Bucharest', 418)]
# ['Arad',
#  'Zerind',
#  'Timisoara',
#  'Sibiu',
#  'Oradea',
#  'Rimnicu',
#  'Lugoj',
#  'Fagaras',
#  'Mehadia',
#  'Pitesti',
#  'Craivo',
#  'Dobreta',
#  'Bucharest']

# %%
#part 2

# %%
import pandas as pd

# %%
def checknodes(nodelist, node):
    for i in nodelist:
        if i == node:
            return True
    return False

# %%
def createDict(filename):
    dic = {}
    df = pd.read_csv(filename, sep=" ",names=["Start", "End", "Cost"] )
    for index, row in df.iterrows():
        if dic.get(row["Start"]) == None:
            dic[row["Start"]] = []
        if not checknodes(dic[row["Start"]], row["End"]):
            dic[row["Start"]].append(row["End"])
        if dic.get(row["End"]) == None:
            dic[row["End"]] = []
        if not checknodes(dic[row["End"]], row["Start"]):
            dic[row["End"]].append(row["Start"])
    return dic

# %%
g  = createDict('graph.txt')

# %%
g
# Out:
# {1.0: [5.0, 6.0],
#  5.0: [1.0, 4.0],
#  6.0: [1.0, 3.0],
#  2.0: [3.0, 4.0, 0.0],
#  3.0: [2.0, 6.0],
#  4.0: [2.0, 5.0],
#  0.0: [2.0]}

# %%
def UCS_path(d,start, goal):
    q = []
    q.append(('Arad',0))
    explored = []
    path = {start: []}
    
    while len(q)>0:

        print('Queue :  ',q)
        node = q.pop(0)   
        
        if node[0] not in explored:
            explored.append(node[0])
        
        if node[0] == goal:
            return path
        
        child = d.get(node[0])
              
        for i in child:

            cost =  i[1] + node[1]
            name = i[0]
            new = (name,cost)

            if new[0] not in explored and new[0] not in build_dcit(q):
                q.append(new)
                path[i[0]] = path[node[0]]+[node[0]]

            elif new[0] in build_dcit(q):

                old_data = build_dcit(q)
                old_cost = old_data[new[0]]
                old_name = new[0]
                old = (old_name,old_cost)
                print("old", old)
                print("new", new)
                if new[1] < old[1]:
                    
                    inde = q.index(old)
                    q[inde] = new
                    path[i[0]] = path[node[0]]+[node[0]]
                else:
                    pass

        
        q = sorted(q,key= my)
        print(50*'*')
        
    

paths = UCS_path(graph,'Arad','Bucharest')
# Out:
# Queue :   [('Arad', 0)]
# {'Sibiu': 140}
# {'Sibiu': 140}
# {'Sibiu': 140, 'Timisoara': 118}
# **************************************************
# Queue :   [('Zerind', 75), ('Timisoara', 118), ('Sibiu', 140)]
# {'Timisoara': 118}
# {'Timisoara': 118, 'Sibiu': 140}
# {'Timisoara': 118}
# {'Timisoara': 118, 'Sibiu': 140}
# **************************************************
# Queue :   [('Timisoara', 118), ('Sibiu', 140), ('Oradea', 146)]
# {'Sibiu': 140}
# {'Sibiu': 140, 'Oradea': 146}
# {'Sibiu': 140}
# {'Sibiu': 140, 'Oradea': 146}
# **************************************************
# Queue :   [('Sibiu', 140), ('Oradea', 146), ('Lugoj', 229)]
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# old ('Oradea', 146)
# new ('Oradea', 291)
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146, 'Lugoj': 229, 'Fagaras': 239}
# **************************************************
# Queue :   [('Oradea', 146), ('Rimnicu', 220), ('Lugoj', 229), ('Fagaras', 239)]
# {'Rimnicu': 220}
# {'Rimnicu': 220, 'Lugoj': 229}
# {'Rimnicu': 220, 'Lugoj': 229, 'Fagaras': 239}
# {'Rimnicu': 220}
# {'Rimnicu': 220, 'Lugoj': 229}
# {'Rimnicu': 220, 'Lugoj': 229, 'Fagaras': 239}
# **************************************************
# Queue :   [('Rimnicu', 220), ('Lugoj', 229), ('Fagaras', 239)]
# {'Lugoj': 229}
# {'Lugoj': 229, 'Fagaras': 239}
# {'Lugoj': 229}
# {'Lugoj': 229, 'Fagaras': 239}
# {'Lugoj': 229}
# {'Lugoj': 229, 'Fagaras': 239}
# {'Lugoj': 229, 'Fagaras': 239, 'Craivo': 366}
# **************************************************
# Queue :   [('Lugoj', 229), ('Fagaras', 239), ('Pitesti', 317), ('Craivo', 366)]
# {'Fagaras': 239}
# {'Fagaras': 239, 'Pitesti': 317}
# {'Fagaras': 239, 'Pitesti': 317, 'Craivo': 366}
# {'Fagaras': 239}
# {'Fagaras': 239, 'Pitesti': 317}
# {'Fagaras': 239, 'Pitesti': 317, 'Craivo': 366}
# **************************************************
# Queue :   [('Fagaras', 239), ('Mehadia', 299), ('Pitesti', 317), ('Craivo', 366)]
# {'Mehadia': 299}
# {'Mehadia': 299, 'Pitesti': 317}
# {'Mehadia': 299, 'Pitesti': 317, 'Craivo': 366}
# {'Mehadia': 299}
# {'Mehadia': 299, 'Pitesti': 317}
# {'Mehadia': 299, 'Pitesti': 317, 'Craivo': 366}
# **************************************************
# Queue :   [('Mehadia', 299), ('Pitesti', 317), ('Craivo', 366), ('Bucharest', 450)]
# {'Pitesti': 317}
# {'Pitesti': 317, 'Craivo': 366}
# {'Pitesti': 317, 'Craivo': 366, 'Bucharest': 450}
# {'Pitesti': 317}
# {'Pitesti': 317, 'Craivo': 366}
# {'Pitesti': 317, 'Craivo': 366, 'Bucharest': 450}
# {'Pitesti': 317, 'Craivo': 366, 'Bucharest': 450, 'Dobreta': 374}
# **************************************************
# Queue :   [('Pitesti', 317), ('Craivo', 366), ('Dobreta', 374), ('Bucharest', 450)]
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# old ('Craivo', 366)
# new ('Craivo', 455)
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# old ('Bucharest', 450)
# new ('Bucharest', 418)
# hlll
# **************************************************
# Queue :   [('Craivo', 366), ('Dobreta', 374), ('Bucharest', 418)]
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# old ('Dobreta', 374)
# new ('Dobreta', 486)
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# **************************************************
# Queue :   [('Dobreta', 374), ('Bucharest', 418)]
# {'Bucharest': 418}
# {'Bucharest': 418}
# **************************************************
# Queue :   [('Bucharest', 418)]

# %%
paths
# Out:
# {'Arad': [],
#  'Sibiu': ['Arad'],
#  'Timisoara': ['Arad'],
#  'Zerind': ['Arad'],
#  'Oradea': ['Arad', 'Zerind'],
#  'Lugoj': ['Arad', 'Timisoara'],
#  'Fagaras': ['Arad', 'Sibiu'],
#  'Rimnicu': ['Arad', 'Sibiu'],
#  'Craivo': ['Arad', 'Sibiu', 'Rimnicu'],
#  'Pitesti': ['Arad', 'Sibiu', 'Rimnicu'],
#  'Mehadia': ['Arad', 'Timisoara', 'Lugoj'],
#  'Bucharest': ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti'],
#  'Dobreta': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']}

# %%
paths["Bucharest"]
# Out:
# ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']

# %%
#part 4

def UCS_path(d,start,goal):
    
    q = []
    q.append(('Arad',0))
    explored = []
    path={start:[]}
    
    while len(q)>0:

        print('Queue :  ',q)
        node = q.pop(0)   
        
        if node[0] not in explored:
            explored.append(node[0])
        
        if node[0] == goal:
            return path 
        
        child = d.get(node[0])
              
        for i in child:

            cost =  i[1] + node[1]
            name = i[0]
            new = (name,cost)

            if new[0] not in explored and new[0] not in build_dcit(q):
                path[i[0]] = path[node[0]]+[node[0]]
                q.append(new) 

            elif new[0] in build_dcit(q):

                old_data = build_dcit(q)
                old_cost = old_data[new[0]]
                old_name = new[0]
                old = (old_name,old_cost)
                print("old", old)
                print("new", new)
                if new[1] < old[1]:
                    print("hlll")
                    inde = q.index(old)
                    q[inde] = new
                    path[i[0]] = path[node[0]]+[node[0]]

                else:
                    pass

        
        q = sorted(q,key= my)
        print(50*'*')
        
paths=UCS_path(graph,'Arad','Bucharest')
# Out:
# Queue :   [('Arad', 0)]
# {'Sibiu': 140}
# {'Sibiu': 140}
# {'Sibiu': 140, 'Timisoara': 118}
# **************************************************
# Queue :   [('Zerind', 75), ('Timisoara', 118), ('Sibiu', 140)]
# {'Timisoara': 118}
# {'Timisoara': 118, 'Sibiu': 140}
# {'Timisoara': 118}
# {'Timisoara': 118, 'Sibiu': 140}
# **************************************************
# Queue :   [('Timisoara', 118), ('Sibiu', 140), ('Oradea', 146)]
# {'Sibiu': 140}
# {'Sibiu': 140, 'Oradea': 146}
# {'Sibiu': 140}
# {'Sibiu': 140, 'Oradea': 146}
# **************************************************
# Queue :   [('Sibiu', 140), ('Oradea', 146), ('Lugoj', 229)]
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# old ('Oradea', 146)
# new ('Oradea', 291)
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146}
# {'Oradea': 146, 'Lugoj': 229}
# {'Oradea': 146, 'Lugoj': 229, 'Fagaras': 239}
# **************************************************
# Queue :   [('Oradea', 146), ('Rimnicu', 220), ('Lugoj', 229), ('Fagaras', 239)]
# {'Rimnicu': 220}
# {'Rimnicu': 220, 'Lugoj': 229}
# {'Rimnicu': 220, 'Lugoj': 229, 'Fagaras': 239}
# {'Rimnicu': 220}
# {'Rimnicu': 220, 'Lugoj': 229}
# {'Rimnicu': 220, 'Lugoj': 229, 'Fagaras': 239}
# **************************************************
# Queue :   [('Rimnicu', 220), ('Lugoj', 229), ('Fagaras', 239)]
# {'Lugoj': 229}
# {'Lugoj': 229, 'Fagaras': 239}
# {'Lugoj': 229}
# {'Lugoj': 229, 'Fagaras': 239}
# {'Lugoj': 229}
# {'Lugoj': 229, 'Fagaras': 239}
# {'Lugoj': 229, 'Fagaras': 239, 'Craivo': 366}
# **************************************************
# Queue :   [('Lugoj', 229), ('Fagaras', 239), ('Pitesti', 317), ('Craivo', 366)]
# {'Fagaras': 239}
# {'Fagaras': 239, 'Pitesti': 317}
# {'Fagaras': 239, 'Pitesti': 317, 'Craivo': 366}
# {'Fagaras': 239}
# {'Fagaras': 239, 'Pitesti': 317}
# {'Fagaras': 239, 'Pitesti': 317, 'Craivo': 366}
# **************************************************
# Queue :   [('Fagaras', 239), ('Mehadia', 299), ('Pitesti', 317), ('Craivo', 366)]
# {'Mehadia': 299}
# {'Mehadia': 299, 'Pitesti': 317}
# {'Mehadia': 299, 'Pitesti': 317, 'Craivo': 366}
# {'Mehadia': 299}
# {'Mehadia': 299, 'Pitesti': 317}
# {'Mehadia': 299, 'Pitesti': 317, 'Craivo': 366}
# **************************************************
# Queue :   [('Mehadia', 299), ('Pitesti', 317), ('Craivo', 366), ('Bucharest', 450)]
# {'Pitesti': 317}
# {'Pitesti': 317, 'Craivo': 366}
# {'Pitesti': 317, 'Craivo': 366, 'Bucharest': 450}
# {'Pitesti': 317}
# {'Pitesti': 317, 'Craivo': 366}
# {'Pitesti': 317, 'Craivo': 366, 'Bucharest': 450}
# {'Pitesti': 317, 'Craivo': 366, 'Bucharest': 450, 'Dobreta': 374}
# **************************************************
# Queue :   [('Pitesti', 317), ('Craivo', 366), ('Dobreta', 374), ('Bucharest', 450)]
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# old ('Craivo', 366)
# new ('Craivo', 455)
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# {'Craivo': 366}
# {'Craivo': 366, 'Dobreta': 374}
# {'Craivo': 366, 'Dobreta': 374, 'Bucharest': 450}
# old ('Bucharest', 450)
# new ('Bucharest', 418)
# hlll
# **************************************************
# Queue :   [('Craivo', 366), ('Dobreta', 374), ('Bucharest', 418)]
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# old ('Dobreta', 374)
# new ('Dobreta', 486)
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# {'Dobreta': 374}
# {'Dobreta': 374, 'Bucharest': 418}
# **************************************************
# Queue :   [('Dobreta', 374), ('Bucharest', 418)]
# {'Bucharest': 418}
# {'Bucharest': 418}
# **************************************************
# Queue :   [('Bucharest', 418)]

# %%
paths
# Out:
# {'Arad': [],
#  'Sibiu': ['Arad'],
#  'Timisoara': ['Arad'],
#  'Zerind': ['Arad'],
#  'Oradea': ['Arad', 'Zerind'],
#  'Lugoj': ['Arad', 'Timisoara'],
#  'Fagaras': ['Arad', 'Sibiu'],
#  'Rimnicu': ['Arad', 'Sibiu'],
#  'Craivo': ['Arad', 'Sibiu', 'Rimnicu'],
#  'Pitesti': ['Arad', 'Sibiu', 'Rimnicu'],
#  'Mehadia': ['Arad', 'Timisoara', 'Lugoj'],
#  'Bucharest': ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti'],
#  'Dobreta': ['Arad', 'Timisoara', 'Lugoj', 'Mehadia']}

# %%
paths["Bucharest"]
# Out:
# ['Arad', 'Sibiu', 'Rimnicu', 'Pitesti']
